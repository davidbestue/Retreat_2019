# %%
#### Analysis rsp alcohol competition
import pandas as pd
import numpy as np
import itertools
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import os
from statsmodels.formula.api import ols
import scikit_posthocs as sp
from function_randomness import randomness_sequence

# %%
os.chdir('C:\\Users\\David\\Documents\\GitHub\\Retreat_2019\\R_S_P\\results')
os.listdir()
# Out:
# ['0_yerko_Tiff.xlsx',
#  '1 _Rocio_Heike.xlsx',
#  '1_alba_david.xlsx',
#  '1_Cris_Amanda.xlsx',
#  '1_genis_jordi.xlsx',
#  '1_jaime_vicky.xlsx',
#  '1_lejla_anna.xlsx',
#  '1_lluis_david.xlsx',
#  '1_lluis_joao.xlsx',
#  '1_lluis_klaus.xlsx',
#  '1_pablo_jorge.xlsx',
#  '2_anna_jordi.xlsx',
#  '2_lluis_klaus.xlsx',
#  '2_Pablo_Jaime.xlsx',
#  '2_vicky_jorge.xlsx']

# %% [markdown]
# ### Load the files into one DataFrame

# %%
#root_save = os.getcwd() + '\\results\\' 
#os.chdir(root_save)

os.listdir()

frames = []
for idx, file in enumerate(os.listdir()):
    df_s = pd.read_excel(file)
    df_s['rounds'] = idx
    randomness_p1 =  round(randomness_sequence(list(df_s['resp1'].values) )[0], 3) 
    randomness_p2 =  round(randomness_sequence(list(df_s['resp2'].values) )[0], 3) 
    df_s['randomness_p1']=randomness_p1
    df_s['randomness_p2']=randomness_p2
    frames.append(df_s)

df = pd.concat(frames, ignore_index=True)
df.head(10)
# Out:
#   player1 player2 resp1 resp2 result winner_round  b_p1  b_p2  repetition  \
# 0   yerko    Tiff     p     r  yerko        yerko     3     3           0
# 1   yerko    Tiff     s     p  yerko        yerko     3     3           0
# 2   yerko    Tiff     s     r   Tiff        yerko     3     3           0
# 3   yerko    Tiff     p     s   Tiff        yerko     3     3           0
# 4   yerko    Tiff     s     p  yerko        yerko     3     3           0
# 5   yerko    Tiff     r     p   Tiff        yerko     3     3           0
# 6   yerko    Tiff     p     s   Tiff        yerko     3     3           0
# 7   yerko    Tiff     s     s   draw        yerko     3     3           0
# 8   yerko    Tiff     s     p  yerko        yerko     3     3           0
# 9   yerko    Tiff     s     r   Tiff        yerko     3     3           0
#
#    p1_lik_1      ...           p2_lik_21     p1_lik_22     p2_lik_22  \
# 0  0.000665      ...        1.227084e-18  1.430363e-19  1.430363e-19
# 1  0.000665      ...        1.227084e-18  1.430363e-19  1.430363e-19
# 2  0.000665      ...        1.227084e-18  1.430363e-19  1.430363e-19
# 3  0.000665      ...        1.227084e-18  1.430363e-19  1.430363e-19
# 4  0.000665      ...        1.227084e-18  1.430363e-19  1.430363e-19
# 5  0.000665      ...        1.227084e-18  1.430363e-19  1.430363e-19
# 6  0.000665      ...        1.227084e-18  1.430363e-19  1.430363e-19
# 7  0.000665      ...        1.227084e-18  1.430363e-19  1.430363e-19
# 8  0.000665      ...        1.227084e-18  1.430363e-19  1.430363e-19
# 9  0.000665      ...        1.227084e-18  1.430363e-19  1.430363e-19
#
#       p1_lik_23     p2_lik_23     p1_lik_24     p2_lik_24  rounds  \
# 0  1.663665e-20  1.663665e-20  1.931154e-21  1.931154e-21       0
# 1  1.663665e-20  1.663665e-20  1.931154e-21  1.931154e-21       0
# 2  1.663665e-20  1.663665e-20  1.931154e-21  1.931154e-21       0
# 3  1.663665e-20  1.663665e-20  1.931154e-21  1.931154e-21       0
# 4  1.663665e-20  1.663665e-20  1.931154e-21  1.931154e-21       0
# 5  1.663665e-20  1.663665e-20  1.931154e-21  1.931154e-21       0
# 6  1.663665e-20  1.663665e-20  1.931154e-21  1.931154e-21       0
# 7  1.663665e-20  1.663665e-20  1.931154e-21  1.931154e-21       0
# 8  1.663665e-20  1.663665e-20  1.931154e-21  1.931154e-21       0
# 9  1.663665e-20  1.663665e-20  1.931154e-21  1.931154e-21       0
#
#    randomness_p1  randomness_p2
# 0          0.003          0.002
# 1          0.003          0.002
# 2          0.003          0.002
# 3          0.003          0.002
# 4          0.003          0.002
# 5          0.003          0.002
# 6          0.003          0.002
# 7          0.003          0.002
# 8          0.003          0.002
# 9          0.003          0.002
#
# [10 rows x 60 columns]

# %% [markdown]
# ### Correlation beer consumption and randomness ?

# %%
beer_n = []
r_value=[]
winner=[]

for r in df['rounds'].unique():
    r_value.append(df.loc[df['rounds']==r,'randomness_p1'].iloc[0])
    r_value.append(df.loc[df['rounds']==r, 'randomness_p2'].iloc[0])
    beer_n.append(df.loc[df['rounds']==r, 'b_p1'].iloc[0])
    beer_n.append(df.loc[df['rounds']==r, 'b_p2'].iloc[0])  



df_b_r = pd.DataFrame({'beer': beer_n, 'rand': r_value})
sns.regplot(df_b_r['beer'], df_b_r['rand'], ci=68, fit_reg=True)
plt.title('Radomness with beer consumption')
plt.xlabel('number of beers')
plt.ylabel('Randomness index')
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)
plt.gca().get_xaxis().tick_bottom()
plt.gca().get_yaxis().tick_left()
plt.show()


#ols
mod = ols('rand ~ beer', data=df_b_r).fit()
print(mod.summary())
# Out:
# C:\Users\David\Anaconda3\envs\python3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   rand   R-squared:                       0.011
# Model:                            OLS   Adj. R-squared:                 -0.024
# Method:                 Least Squares   F-statistic:                    0.3187
# Date:                Tue, 12 Feb 2019   Prob (F-statistic):              0.577
# Time:                        16:37:32   Log-Likelihood:                 158.37
# No. Observations:                  30   AIC:                            -312.7
# Df Residuals:                      28   BIC:                            -309.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0030      0.000      7.696      0.000       0.002       0.004
# beer        5.374e-05   9.52e-05      0.565      0.577      -0.000       0.000
# ==============================================================================
# Omnibus:                       27.211   Durbin-Watson:                   2.160
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               56.558
# Skew:                           1.959   Prob(JB):                     5.23e-13
# Kurtosis:                       8.468   Cond. No.                         7.07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
probs_1 = ['p1_lik_1', 'p1_lik_2', 'p1_lik_3', 'p1_lik_4', 'p1_lik_5', 'p1_lik_6', 'p1_lik_7','p1_lik_8','p1_lik_9',
           'p1_lik_10', 'p1_lik_11', 'p1_lik_12', 'p1_lik_13', 'p1_lik_14', 'p1_lik_15', 'p1_lik_16', 'p1_lik_17', 
            'p1_lik_18', 'p1_lik_19', 'p1_lik_20', 'p1_lik_21', 'p1_lik_22', 'p1_lik_23', 'p1_lik_24']

probs_2 = ['p2_lik_1', 'p2_lik_2', 'p2_lik_3', 'p2_lik_4', 'p2_lik_5', 'p2_lik_6', 'p2_lik_7','p2_lik_8','p2_lik_9',
           'p2_lik_10', 'p2_lik_11', 'p2_lik_12', 'p2_lik_13', 'p2_lik_14', 'p2_lik_15', 'p2_lik_16', 'p2_lik_17', 
            'p2_lik_18', 'p2_lik_19', 'p2_lik_20', 'p2_lik_21', 'p2_lik_22', 'p2_lik_23', 'p2_lik_24']


           
for probs in range(0, len(probs_1)):
    ##         
    beer_n = []
    r_value=[]
    winner=[]

    for r in df['rounds'].unique():
        r_value.append(df.loc[df['rounds']==r, probs_1[probs]].iloc[0])
        r_value.append(df.loc[df['rounds']==r, probs_2[probs]].iloc[0])
        beer_n.append(df.loc[df['rounds']==r, 'b_p1'].iloc[0])
        beer_n.append(df.loc[df['rounds']==r, 'b_p2'].iloc[0])  



    df_b_r = pd.DataFrame({'beer': beer_n, 'rand': r_value})
    sns.regplot(df_b_r['beer'], df_b_r['rand'], ci=68, fit_reg=True)
    plt.title('Radomness with beer consumption')
    plt.xlabel('number of beers')
    plt.ylabel('Randomness index')
    plt.gca().spines['right'].set_visible(False)
    plt.gca().spines['top'].set_visible(False)
    plt.gca().get_xaxis().tick_bottom()
    plt.gca().get_yaxis().tick_left()
    plt.show()


    #ols
    mod = ols('rand ~ beer', data=df_b_r).fit()
    print(mod.summary())
# Out:
# C:\Users\David\Anaconda3\envs\python3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   rand   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                 -0.031
# Method:                 Least Squares   F-statistic:                    0.1209
# Date:                Tue, 12 Feb 2019   Prob (F-statistic):              0.731
# Time:                        16:37:32   Log-Likelihood:                 160.87
# No. Observations:                  30   AIC:                            -317.7
# Df Residuals:                      28   BIC:                            -314.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0009      0.000      2.422      0.022       0.000       0.002
# beer        3.045e-05   8.76e-05      0.348      0.731      -0.000       0.000
# ==============================================================================
# Omnibus:                       43.872   Durbin-Watson:                   2.335
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              181.148
# Skew:                           2.986   Prob(JB):                     4.62e-40
# Kurtosis:                      13.452   Cond. No.                         7.07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   rand   R-squared:                       0.045
# Model:                            OLS   Adj. R-squared:                  0.011
# Method:                 Least Squares   F-statistic:                     1.308
# Date:                Tue, 12 Feb 2019   Prob (F-statistic):              0.262
# Time:                        16:37:33   Log-Likelihood:                 178.30
# No. Observations:                  30   AIC:                            -352.6
# Df Residuals:                      28   BIC:                            -349.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0011      0.000      5.569      0.000       0.001       0.002
# beer        5.602e-05    4.9e-05      1.144      0.262   -4.43e-05       0.000
# ==============================================================================
# Omnibus:                        2.263   Durbin-Watson:                   1.637
# Prob(Omnibus):                  0.323   Jarque-Bera (JB):                2.038
# Skew:                           0.574   Prob(JB):                        0.361
# Kurtosis:                       2.442   Cond. No.                         7.07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   rand   R-squared:                       0.064
# Model:                            OLS   Adj. R-squared:                  0.030
# Method:                 Least Squares   F-statistic:                     1.910
# Date:                Tue, 12 Feb 2019   Prob (F-statistic):              0.178
# Time:                        16:37:33   Log-Likelihood:                 231.21
# No. Observations:                  30   AIC:                            -458.4
# Df Residuals:                      28   BIC:                            -455.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0009   3.43e-05     25.962      0.000       0.001       0.001
# beer        1.161e-05    8.4e-06      1.382      0.178    -5.6e-06    2.88e-05
# ==============================================================================
# Omnibus:                        0.126   Durbin-Watson:                   1.958
# Prob(Omnibus):                  0.939   Jarque-Bera (JB):                0.237
# Skew:                          -0.136   Prob(JB):                        0.888
# Kurtosis:                       2.659   Cond. No.                         7.07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   rand   R-squared:                       0.086
# Model:                            OLS   Adj. R-squared:                  0.053
# Method:                 Least Squares   F-statistic:                     2.627
# Date:                Tue, 12 Feb 2019   Prob (F-statistic):              0.116
# Time:                        16:37:33   Log-Likelihood:                 293.13
# No. Observations:                  30   AIC:                            -582.3
# Df Residuals:                      28   BIC:                            -579.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0003   4.35e-06     72.439      0.000       0.000       0.000
# beer        1.728e-06   1.07e-06      1.621      0.116   -4.56e-07    3.91e-06
# ==============================================================================
# Omnibus:                       11.452   Durbin-Watson:                   1.084
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):               10.799
# Skew:                           1.139   Prob(JB):                      0.00452
# Kurtosis:                       4.856   Cond. No.                         7.07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   rand   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.035
# Method:                 Least Squares   F-statistic:                   0.01393
# Date:                Tue, 12 Feb 2019   Prob (F-statistic):              0.907
# Time:                        16:37:34   Log-Likelihood:                 368.64
# No. Observations:                  30   AIC:                            -733.3
# Df Residuals:                      28   BIC:                            -730.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   7.323e-05   3.51e-07    208.523      0.000    7.25e-05     7.4e-05
# beer        1.015e-08    8.6e-08      0.118      0.907   -1.66e-07    1.86e-07
# ==============================================================================
# Omnibus:                       16.356   Durbin-Watson:                   2.295
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               17.654
# Skew:                           1.614   Prob(JB):                     0.000147
# Kurtosis:                       4.923   Cond. No.                         7.07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   rand   R-squared:                       0.054
# Model:                            OLS   Adj. R-squared:                  0.020
# Method:                 Least Squares   F-statistic:                     1.591
# Date:                Tue, 12 Feb 2019   Prob (F-statistic):              0.218
# Time:                        16:37:34   Log-Likelihood:                 459.69
# No. Observations:                  30   AIC:                            -915.4
# Df Residuals:                      28   BIC:                            -912.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1.386e-05   1.69e-08    820.873      0.000    1.38e-05    1.39e-05
# beer        5.218e-09   4.14e-09      1.261      0.218   -3.26e-09    1.37e-08
# ==============================================================================
# Omnibus:                       24.509   Durbin-Watson:                   2.612
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               35.450
# Skew:                           2.121   Prob(JB):                     2.01e-08
# Kurtosis:                       6.219   Cond. No.                         7.07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   rand   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                 -0.026
# Method:                 Least Squares   F-statistic:                    0.2606
# Date:                Tue, 12 Feb 2019   Prob (F-statistic):              0.614
# Time:                        16:37:34   Log-Likelihood:                 512.52
# No. Observations:                  30   AIC:                            -1021.
# Df Residuals:                      28   BIC:                            -1018.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   2.353e-06    2.9e-09    810.797      0.000    2.35e-06    2.36e-06
# beer       -3.628e-10   7.11e-10     -0.510      0.614   -1.82e-09    1.09e-09
# ==============================================================================
# Omnibus:                       71.413   Durbin-Watson:                   2.043
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              882.842
# Skew:                           5.123   Prob(JB):                    1.96e-192
# Kurtosis:                      27.521   Cond. No.                         7.07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   rand   R-squared:                       0.163
# Model:                            OLS   Adj. R-squared:                  0.134
# Method:                 Least Squares   F-statistic:                     5.471
# Date:                Tue, 12 Feb 2019   Prob (F-statistic):             0.0267
# Time:                        16:37:35   Log-Likelihood:                 916.34
# No. Observations:                  30   AIC:                            -1829.
# Df Residuals:                      28   BIC:                            -1826.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   3.721e-07   4.14e-15   8.99e+07      0.000    3.72e-07    3.72e-07
# beer        2.371e-15   1.01e-15      2.339      0.027    2.95e-16    4.45e-15
# ==============================================================================
# Omnibus:                        4.142   Durbin-Watson:                   1.270
# Prob(Omnibus):                  0.126   Jarque-Bera (JB):                3.622
# Skew:                          -0.775   Prob(JB):                        0.164
# Kurtosis:                       2.295   Cond. No.                         7.07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   rand   R-squared:                       0.163
# Model:                            OLS   Adj. R-squared:                  0.134
# Method:                 Least Squares   F-statistic:                     5.471
# Date:                Tue, 12 Feb 2019   Prob (F-statistic):             0.0267
# Time:                        16:37:35   Log-Likelihood:                 1038.0
# No. Observations:                  30   AIC:                            -2072.
# Df Residuals:                      28   BIC:                            -2069.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   5.613e-08   7.16e-17   7.84e+08      0.000    5.61e-08    5.61e-08
# beer        4.103e-17   1.75e-17      2.339      0.027     5.1e-18     7.7e-17
# ==============================================================================
# Omnibus:                        4.142   Durbin-Watson:                   1.270
# Prob(Omnibus):                  0.126   Jarque-Bera (JB):                3.622
# Skew:                          -0.775   Prob(JB):                        0.164
# Kurtosis:                       2.295   Cond. No.                         7.07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   rand   R-squared:                       0.163
# Model:                            OLS   Adj. R-squared:                  0.134
# Method:                 Least Squares   F-statistic:                     5.471
# Date:                Tue, 12 Feb 2019   Prob (F-statistic):             0.0267
# Time:                        16:37:35   Log-Likelihood:                 1161.3
# No. Observations:                  30   AIC:                            -2319.
# Df Residuals:                      28   BIC:                            -2316.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   8.079e-09   1.18e-18   6.87e+09      0.000    8.08e-09    8.08e-09
# beer         6.74e-19   2.88e-19      2.339      0.027    8.38e-20    1.26e-18
# ==============================================================================
# Omnibus:                        4.142   Durbin-Watson:                   1.270
# Prob(Omnibus):                  0.126   Jarque-Bera (JB):                3.622
# Skew:                          -0.775   Prob(JB):                        0.164
# Kurtosis:                       2.295   Cond. No.                         7.07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   rand   R-squared:                       0.163
# Model:                            OLS   Adj. R-squared:                  0.134
# Method:                 Least Squares   F-statistic:                     5.471
# Date:                Tue, 12 Feb 2019   Prob (F-statistic):             0.0267
# Time:                        16:37:35   Log-Likelihood:                 1284.2
# No. Observations:                  30   AIC:                            -2564.
# Df Residuals:                      28   BIC:                            -2562.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    1.16e-09   1.95e-20   5.94e+10      0.000    1.16e-09    1.16e-09
# beer        1.119e-20   4.78e-21      2.339      0.027    1.39e-21     2.1e-20
# ==============================================================================
# Omnibus:                        4.142   Durbin-Watson:                   1.270
# Prob(Omnibus):                  0.126   Jarque-Bera (JB):                3.622
# Skew:                          -0.775   Prob(JB):                        0.164
# Kurtosis:                       2.295   Cond. No.                         7.07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   rand   R-squared:                       0.163
# Model:                            OLS   Adj. R-squared:                  0.134
# Method:                 Least Squares   F-statistic:                     5.471
# Date:                Tue, 12 Feb 2019   Prob (F-statistic):             0.0267
# Time:                        16:37:36   Log-Likelihood:                 1408.8
# No. Observations:                  30   AIC:                            -2814.
# Df Residuals:                      28   BIC:                            -2811.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1.597e-10   3.08e-22   5.19e+11      0.000     1.6e-10     1.6e-10
# beer        1.762e-22   7.53e-23      2.339      0.027    2.19e-23    3.31e-22
# ==============================================================================
# Omnibus:                        4.142   Durbin-Watson:                   1.270
# Prob(Omnibus):                  0.126   Jarque-Bera (JB):                3.622
# Skew:                          -0.775   Prob(JB):                        0.163
# Kurtosis:                       2.295   Cond. No.                         7.07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   rand   R-squared:                       0.163
# Model:                            OLS   Adj. R-squared:                  0.134
# Method:                 Least Squares   F-statistic:                     5.471
# Date:                Tue, 12 Feb 2019   Prob (F-statistic):             0.0267
# Time:                        16:37:36   Log-Likelihood:                 1533.7
# No. Observations:                  30   AIC:                            -3063.
# Df Residuals:                      28   BIC:                            -3061.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   2.162e-11   4.78e-24   4.52e+12      0.000    2.16e-11    2.16e-11
# beer        2.738e-24   1.17e-24      2.338      0.027    3.39e-25    5.14e-24
# ==============================================================================
# Omnibus:                        4.144   Durbin-Watson:                   1.270
# Prob(Omnibus):                  0.126   Jarque-Bera (JB):                3.623
# Skew:                          -0.775   Prob(JB):                        0.163
# Kurtosis:                       2.295   Cond. No.                         7.07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   rand   R-squared:                       0.163
# Model:                            OLS   Adj. R-squared:                  0.134
# Method:                 Least Squares   F-statistic:                     5.473
# Date:                Tue, 12 Feb 2019   Prob (F-statistic):             0.0267
# Time:                        16:37:36   Log-Likelihood:                 1657.5
# No. Observations:                  30   AIC:                            -3311.
# Df Residuals:                      28   BIC:                            -3308.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   2.981e-12   7.71e-26   3.87e+13      0.000    2.98e-12    2.98e-12
# beer        4.397e-26   1.89e-26      2.328      0.027    5.29e-27    8.27e-26
# ==============================================================================
# Omnibus:                        4.170   Durbin-Watson:                   1.269
# Prob(Omnibus):                  0.124   Jarque-Bera (JB):                3.645
# Skew:                          -0.777   Prob(JB):                        0.162
# Kurtosis:                       2.293   Cond. No.                         7.07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   rand   R-squared:                       0.164
# Model:                            OLS   Adj. R-squared:                  0.134
# Method:                 Least Squares   F-statistic:                     5.489
# Date:                Tue, 12 Feb 2019   Prob (F-statistic):             0.0265
# Time:                        16:37:37   Log-Likelihood:                 1783.1
# No. Observations:                  30   AIC:                            -3562.
# Df Residuals:                      28   BIC:                            -3559.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   3.955e-13   1.17e-27   3.38e+14      0.000    3.96e-13    3.96e-13
# beer        6.532e-28   2.87e-28      2.277      0.031    6.57e-29    1.24e-27
# ==============================================================================
# Omnibus:                        4.262   Durbin-Watson:                   1.266
# Prob(Omnibus):                  0.119   Jarque-Bera (JB):                3.727
# Skew:                          -0.787   Prob(JB):                        0.155
# Kurtosis:                       2.290   Cond. No.                         7.07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   rand   R-squared:                       0.075
# Model:                            OLS   Adj. R-squared:                  0.042
# Method:                 Least Squares   F-statistic:                     2.267
# Date:                Tue, 12 Feb 2019   Prob (F-statistic):              0.143
# Time:                        16:37:37   Log-Likelihood:                 1910.2
# No. Observations:                  30   AIC:                            -3816.
# Df Residuals:                      28   BIC:                            -3814.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   5.109e-14   1.69e-29   3.02e+15      0.000    5.11e-14    5.11e-14
# beer        6.311e-30   4.15e-30      1.522      0.139   -2.18e-30    1.48e-29
# ==============================================================================
# Omnibus:                        5.819   Durbin-Watson:                   1.135
# Prob(Omnibus):                  0.055   Jarque-Bera (JB):                5.022
# Skew:                          -0.916   Prob(JB):                       0.0812
# Kurtosis:                       2.189   Cond. No.                         7.07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   rand   R-squared:                      -1.819
# Model:                            OLS   Adj. R-squared:                 -1.920
# Method:                 Least Squares   F-statistic:                    -18.07
# Date:                Tue, 12 Feb 2019   Prob (F-statistic):               1.00
# Time:                        16:37:37   Log-Likelihood:                 2008.2
# No. Observations:                  30   AIC:                            -4012.
# Df Residuals:                      28   BIC:                            -4010.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    6.47e-15   6.47e-31      1e+16      0.000    6.47e-15    6.47e-15
# beer       -1.972e-31   1.58e-31     -1.245      0.223   -5.22e-31    1.27e-31
# ==============================================================================
# Omnibus:                        4.597   Durbin-Watson:                   0.512
# Prob(Omnibus):                  0.100   Jarque-Bera (JB):                3.929
# Skew:                          -0.799   Prob(JB):                        0.140
# Kurtosis:                       2.232   Cond. No.                         7.07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# C:\Users\David\Anaconda3\envs\python3\lib\site-packages\statsmodels\regression\linear_model.py:1543: RuntimeWarning: divide by zero encountered in double_scalars
#   return 1 - self.ssr/self.centered_tss
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   rand   R-squared:                        -inf
# Model:                            OLS   Adj. R-squared:                   -inf
# Method:                 Least Squares   F-statistic:                    -28.00
# Date:                Tue, 12 Feb 2019   Prob (F-statistic):               1.00
# Time:                        16:37:38   Log-Likelihood:                 2072.3
# No. Observations:                  30   AIC:                            -4141.
# Df Residuals:                      28   BIC:                            -4138.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   7.628e-16   7.63e-32      1e+16      0.000    7.63e-16    7.63e-16
# beer       -3.698e-32   1.87e-32     -1.978      0.058   -7.53e-32    1.31e-33
# ==============================================================================
# Omnibus:                        1.436   Durbin-Watson:                   0.287
# Prob(Omnibus):                  0.488   Jarque-Bera (JB):                1.079
# Skew:                           0.457   Prob(JB):                        0.583
# Kurtosis:                       2.835   Cond. No.                         7.07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   rand   R-squared:                       0.436
# Model:                            OLS   Adj. R-squared:                  0.415
# Method:                 Least Squares   F-statistic:                     21.61
# Date:                Tue, 12 Feb 2019   Prob (F-statistic):           7.25e-05
# Time:                        16:37:38   Log-Likelihood:                 2134.4
# No. Observations:                  30   AIC:                            -4265.
# Df Residuals:                      28   BIC:                            -4262.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   8.963e-17   9.62e-33   9.32e+15      0.000    8.96e-17    8.96e-17
# beer       -5.393e-33   2.36e-33     -2.289      0.030   -1.02e-32   -5.67e-34
# ==============================================================================
# Omnibus:                        1.371   Durbin-Watson:                   0.418
# Prob(Omnibus):                  0.504   Jarque-Bera (JB):                0.950
# Skew:                           0.037   Prob(JB):                        0.622
# Kurtosis:                       2.132   Cond. No.                         7.07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   rand   R-squared:                       0.233
# Model:                            OLS   Adj. R-squared:                  0.206
# Method:                 Least Squares   F-statistic:                     8.522
# Date:                Tue, 12 Feb 2019   Prob (F-statistic):            0.00685
# Time:                        16:37:38   Log-Likelihood:                 2207.2
# No. Observations:                  30   AIC:                            -4410.
# Df Residuals:                      28   BIC:                            -4408.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    1.05e-17    8.5e-34   1.24e+16      0.000    1.05e-17    1.05e-17
# beer       -6.741e-34   2.08e-34     -3.237      0.003    -1.1e-33   -2.48e-34
# ==============================================================================
# Omnibus:                        1.912   Durbin-Watson:                   0.630
# Prob(Omnibus):                  0.384   Jarque-Bera (JB):                1.587
# Skew:                           0.415   Prob(JB):                        0.452
# Kurtosis:                       2.238   Cond. No.                         7.07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   rand   R-squared:                        -inf
# Model:                            OLS   Adj. R-squared:                   -inf
# Method:                 Least Squares   F-statistic:                    -28.00
# Date:                Tue, 12 Feb 2019   Prob (F-statistic):               1.00
# Time:                        16:37:38   Log-Likelihood:                 2259.4
# No. Observations:                  30   AIC:                            -4515.
# Df Residuals:                      28   BIC:                            -4512.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1.227e-18   1.49e-34   8.23e+15      0.000    1.23e-18    1.23e-18
# beer       -7.222e-35   3.65e-35     -1.978      0.058   -1.47e-34    2.57e-36
# ==============================================================================
# Omnibus:                        1.436   Durbin-Watson:                   0.287
# Prob(Omnibus):                  0.488   Jarque-Bera (JB):                1.079
# Skew:                           0.457   Prob(JB):                        0.583
# Kurtosis:                       2.835   Cond. No.                         7.07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   rand   R-squared:                      -1.058
# Model:                            OLS   Adj. R-squared:                 -1.132
# Method:                 Least Squares   F-statistic:                    -14.40
# Date:                Tue, 12 Feb 2019   Prob (F-statistic):               1.00
# Time:                        16:37:39   Log-Likelihood:                 2317.2
# No. Observations:                  30   AIC:                            -4630.
# Df Residuals:                      28   BIC:                            -4628.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    1.43e-19   2.18e-35   6.57e+15      0.000    1.43e-19    1.43e-19
# beer       -1.204e-35   5.33e-36     -2.258      0.032    -2.3e-35   -1.12e-36
# ==============================================================================
# Omnibus:                        1.649   Durbin-Watson:                   0.320
# Prob(Omnibus):                  0.438   Jarque-Bera (JB):                1.094
# Skew:                           0.468   Prob(JB):                        0.579
# Kurtosis:                       2.975   Cond. No.                         7.07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   rand   R-squared:                      -0.100
# Model:                            OLS   Adj. R-squared:                 -0.139
# Method:                 Least Squares   F-statistic:                    -2.545
# Date:                Tue, 12 Feb 2019   Prob (F-statistic):               1.00
# Time:                        16:37:39   Log-Likelihood:                 2409.7
# No. Observations:                  30   AIC:                            -4815.
# Df Residuals:                      28   BIC:                            -4813.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1.664e-20   9.94e-37   1.67e+16      0.000    1.66e-20    1.66e-20
# beer       -1.128e-36   2.44e-37     -4.633      0.000   -1.63e-36   -6.29e-37
# ==============================================================================
# Omnibus:                        1.436   Durbin-Watson:                   1.576
# Prob(Omnibus):                  0.488   Jarque-Bera (JB):                1.079
# Skew:                           0.457   Prob(JB):                        0.583
# Kurtosis:                       2.835   Cond. No.                         7.07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   rand   R-squared:                        -inf
# Model:                            OLS   Adj. R-squared:                   -inf
# Method:                 Least Squares   F-statistic:                    -28.00
# Date:                Tue, 12 Feb 2019   Prob (F-statistic):               1.00
# Time:                        16:37:39   Log-Likelihood:                 2472.1
# No. Observations:                  30   AIC:                            -4940.
# Df Residuals:                      28   BIC:                            -4937.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1.931e-21   1.24e-37   1.55e+16      0.000    1.93e-21    1.93e-21
# beer       -9.404e-38   3.04e-38     -3.088      0.005   -1.56e-37   -3.17e-38
# ==============================================================================
# Omnibus:                        3.374   Durbin-Watson:                   0.697
# Prob(Omnibus):                  0.185   Jarque-Bera (JB):                1.954
# Skew:                           0.376   Prob(JB):                        0.376
# Kurtosis:                       2.001   Cond. No.                         7.07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## Is beeing random a good strategy to win?

# %%
v1 = df.loc[df['rounds']==r, 'randomness_p1'].iloc[0]
v2 = df.loc[df['rounds']==r, 'randomness_p2'].iloc[0]

np.mean([v1, v2])
#print(v1, v2)
# Out:
# 0.003

# %%
### I create a draw mean value by combing bothe the random value and beer consumption of the participants

w_r_value=[]
l_r_value=[]
d_r_value=[]

w_b=[]
l_b=[]
d_b=[]


for r in df['rounds'].unique():
    win = df.loc[df['rounds']==r, 'winner_round'].iloc[0]
    if win == df.loc[df['rounds']==r, 'player1'].iloc[0]:
        w_r_value.append(df.loc[df['rounds']==r, 'randomness_p1'].iloc[0])
        l_r_value.append(df.loc[df['rounds']==r, 'randomness_p2'].iloc[0])
        w_b.append(df.loc[df['rounds']==r, 'b_p1'].iloc[0])
        l_b.append(df.loc[df['rounds']==r, 'b_p2'].iloc[0])  
    elif win == df.loc[df['rounds']==r, 'player2'].iloc[0]:
        w_r_value.append(df.loc[df['rounds']==r, 'randomness_p2'].iloc[0])
        l_r_value.append(df.loc[df['rounds']==r, 'randomness_p1'].iloc[0])
        w_b.append(df.loc[df['rounds']==r, 'b_p2'].iloc[0])
        l_b.append(df.loc[df['rounds']==r, 'b_p1'].iloc[0])
    else: ## draw
        d_r_value.append(df.loc[df['rounds']==r, 'randomness_p2'].iloc[0] ) 
        d_r_value.append( df.loc[df['rounds']==r, 'randomness_p1'].iloc[0] )
        d_b.append(df.loc[df['rounds']==r, 'b_p2'].iloc[0] )
        d_b.append(df.loc[df['rounds']==r, 'b_p1'].iloc[0] )

        

### Dataframe for each    
df_win = pd.DataFrame({'beer': w_b, 'rand': w_r_value})
df_win['winners'] = 'winner'
df_l = pd.DataFrame({'beer': l_b, 'rand': l_r_value})
df_l['winners'] = 'looser'
df_d = pd.DataFrame({'beer': d_b, 'rand': d_r_value})
df_d['winners'] = 'draw'
#concatenate them
df_w_l=pd.concat([df_win, df_l, df_d], ignore_index=True)

#Difference in mean randomness?
sns.factorplot(x='winners', y='rand', data=df_w_l, kind='bar')
plt.title('Randomnes and victory')
plt.show()

#mod = ols('rand ~ winners', data=df_w_l).fit()
#print(mod.summary())

pc = sp.posthoc_tukey(df_w_l, val_col='rand', group_col='winners') 
heatmap_args = {'linewidths': 0.25, 'linecolor': '0.5', 'clip_on': False, 'square': True, 'cbar_ax_bbox': [0.80, 0.35, 0.04, 0.3]}
sp.sign_plot(pc, **heatmap_args)
plt.show()
print(pc)
# Out:
# C:\Users\David\Anaconda3\envs\python3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\David\Anaconda3\envs\python3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
#           winner    looser  draw
# winner -1.000000  0.733419   0.9
# looser  0.733419 -1.000000   0.9
# draw    0.900000  0.900000  -1.0

# %% [markdown]
# ### Is drinking a goos strategy?

# %%
#Difference in mean randomness?
sns.factorplot(x='winners', y='beer', data=df_w_l, kind='bar')
plt.title('Beers and victory')
plt.show()

pc = sp.posthoc_tukey(df_w_l, val_col='beer', group_col='winners') 
heatmap_args = {'linewidths': 0.25, 'linecolor': '0.5', 'clip_on': False, 'square': True, 'cbar_ax_bbox': [0.80, 0.35, 0.04, 0.3]}
sp.sign_plot(pc, **heatmap_args)
plt.show()
pc
# Out:
# C:\Users\David\Anaconda3\envs\python3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\David\Anaconda3\envs\python3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
#           winner    looser      draw
# winner -1.000000  0.759002  0.332333
# looser  0.759002 -1.000000  0.519981
# draw    0.332333  0.519981 -1.000000

# %%
## Dimple regression model where we try to explain randomness as a function of beer consumption and as a winning strategy
mod = ols('rand ~ beer * C(winners)', data=df_w_l).fit()
print(mod.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   rand   R-squared:                       0.136
# Model:                            OLS   Adj. R-squared:                 -0.044
# Method:                 Least Squares   F-statistic:                    0.7552
# Date:                Tue, 12 Feb 2019   Prob (F-statistic):              0.591
# Time:                        16:37:40   Log-Likelihood:                 160.39
# No. Observations:                  30   AIC:                            -308.8
# Df Residuals:                      24   BIC:                            -300.4
# Df Model:                           5
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                    -0.0080      0.010     -0.795      0.435      -0.029       0.013
# C(winners)[T.looser]          0.0104      0.010      1.036      0.311      -0.010       0.031
# C(winners)[T.winner]          0.0116      0.010      1.153      0.260      -0.009       0.032
# beer                          0.0020      0.002      1.097      0.284      -0.002       0.006
# beer:C(winners)[T.looser]    -0.0018      0.002     -1.006      0.324      -0.006       0.002
# beer:C(winners)[T.winner]    -0.0021      0.002     -1.146      0.263      -0.006       0.002
# ==============================================================================
# Omnibus:                       30.285   Durbin-Watson:                   2.651
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               74.311
# Skew:                           2.106   Prob(JB):                     7.30e-17
# Kurtosis:                       9.459   Cond. No.                         375.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
